# %% [markdown]
# ## Librerías

# %%
import cv2
from PIL import Image
import numpy as np
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Lectura de imagen y sus dimensiones

# %%
img_path = '../../img'
img = cv2.imread(f'{img_path}/Google-self-driving-car-007.jpg')

# %%
img.shape
print(f'altura = {int(img.shape[0])}, pixels')
print(f'anchura = {int(img.shape[1])}, pixels')
# Out:
# altura = 720, pixels
# anchura = 960, pixels

# %% [markdown]
# ## Despligue de imagen con OpenCV en una ventana independiente

# %%
cv2.imshow('Google self driving car', img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ## Usando Matplotlib

# %%
rgb_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(rgb_img)
rgb_img.shape
# Out:
# (720, 960, 3)

# %% [markdown]
# ## Conversión de imagen en escala de grises

# %%
gray_img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
cv2.imshow('Google self driving car in grayscale', gray_img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
gray_img.shape
# Out:
# (720, 960)

# %% [markdown]
# ## Conversión en un arreglo bidemensional de Numpy

# %%
img_arr = np.asarray(rgb_img)
img_arr.shape
plt.imshow(img_arr)

# %% [markdown]
# ## Usando PIL

# %%
img2 = Image.open(f'{img_path}/Google-self-driving-car-007.jpg')

# %% [markdown]
# ## Convertir imagen en arreglo

# %%
img2_arr = np.asarray(img2)
img2_arr.shape
plt.imshow(img2_arr)

# %% [markdown]
# ## Crear una copia y mostrar en plano rojo

# %%
img_red = img2_arr.copy()
# plano verde se hace cero
img_red[:,:,1] = 0
# plano azul se hace cero
img_red[:,:,2] = 0
plt.imshow(img_red)

# %% [markdown]
# ## Conversión a espacio HSV

# %%
hsv_img = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)
cv2.imshow('Google self driving car in HSV', hsv_img)
cv2.waitKey()
cv2.destroyAllWindows()

# %% [markdown]
# ## Visualización canal de Hue

# %%
plt.imshow(hsv_img[:,:,0])
plt.title('Hue')
# Out:
# Text(0.5, 1.0, 'Hue')

# %% [markdown]
# ## Visualización canal de Saturation

# %%
plt.imshow(hsv_img[:,:,1])
plt.title('Saturation')
# Out:
# Text(0.5, 1.0, 'Saturation')

# %% [markdown]
# ## Visualización canal de Value

# %%
plt.imshow(hsv_img[:,:,2])
plt.title('Value')
# Out:
# Text(0.5, 1.0, 'Value')
